# %% [markdown]
# ## This Notebook contains code an notes from Udacity Data Science Class

# %% [markdown]
# ### The First Problem is the Kaggle Titanic Simple Survival Heuristic

# %%
# Load required libraries

import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
file_path = '/home/skerr/DataSets/Kaggle/Titanic/train.csv'

# %%
predictions = {}
df = pd.read_csv(file_path)
for passenger_index, passenger in df.iterrows():
    passenger_id = passenger['PassengerId']
    if passenger['Sex'] == 'female':
        predictions[passenger_id] = 1
    else:
        predictions[passenger_id] = 0
predictions
# Out:
# {1L: 0,
#  2L: 1,
#  3L: 1,
#  4L: 1,
#  5L: 0,
#  6L: 0,
#  7L: 0,
#  8L: 0,
#  9L: 1,
#  10L: 1,
#  11L: 1,
#  12L: 1,
#  13L: 0,
#  14L: 0,
#  15L: 1,
#  16L: 1,
#  17L: 0,
#  18L: 0,
#  19L: 1,
#  20L: 1,
#  21L: 0,
#  22L: 0,
#  23L: 1,
#  24L: 0,
#  25L: 1,
#  26L: 1,
#  27L: 0,
#  28L: 0,
#  29L: 1,
#  30L: 0,
#  31L: 0,
#  32L: 1,
#  33L: 1,
#  34L: 0,
#  35L: 0,
#  36L: 0,
#  37L: 0,
#  38L: 0,
#  39L: 1,
#  40L: 1,
#  41L: 1,
#  42L: 1,
#  43L: 0,
#  44L: 1,
#  45L: 1,
#  46L: 0,
#  47L: 0,
#  48L: 1,
#  49L: 0,
#  50L: 1,
#  51L: 0,
#  52L: 0,
#  53L: 1,
#  54L: 1,
#  55L: 0,
#  56L: 0,
#  57L: 1,
#  58L: 0,
#  59L: 1,
#  60L: 0,
#  61L: 0,
#  62L: 1,
#  63L: 0,
#  64L: 0,
#  65L: 0,
#  66L: 0,
#  67L: 1,
#  68L: 0,
#  69L: 1,
#  70L: 0,
#  71L: 0,
#  72L: 1,
#  73L: 0,
#  74L: 0,
#  75L: 0,
#  76L: 0,
#  77L: 0,
#  78L: 0,
#  79L: 0,
#  80L: 1,
#  81L: 0,
#  82L: 0,
#  83L: 1,
#  84L: 0,
#  85L: 1,
#  86L: 1,
#  87L: 0,
#  88L: 0,
#  89L: 1,
#  90L: 0,
#  91L: 0,
# ...

# %%
# Now for some exploration not part of the class
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df[df.Age < 1]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 78   0.83      0      2  248738   29.0000      NaN        S
# 305  0.92      1      2  113781  151.5500  C22 C26        S
# 469  0.75      2      1    2666   19.2583      NaN        C
# 644  0.75      2      1    2666   19.2583      NaN        C
# ...

# %%
# Let's find how many survivors we predicted
# First change predictions dictionary to a pandas dataframe (to make analysis easier)
pred_simp_df = pd.DataFrame(predictions.items(), columns = ['Id','Survival'])
pred_simp_df[pred_simp_df.Survival == 1].count()
# Out:
# Id          314
# Survival    314
# dtype: int64

# %% [markdown]
# ### The Second problem is the Kaggle Titanic Complex Heuristic

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
file_path = '/home/skerr/DataSets/Kaggle/Titanic/train.csv'
df = pd.read_csv(file_path)
predictions = {}

# %%
for passenger_index, passenger in df.iterrows():
    passenger_id = passenger['PassengerId']
    if passenger['Sex'] == 'female':
        predictions[passenger_id] = 1
    elif (passenger['Pclass'] == 1 and passenger['Age'] < 18):
        predictions[passenger_id] = 1
    else:
        predictions[passenger_id] = 0
predictions
# Out:
# {1L: 0,
#  2L: 1,
#  3L: 1,
#  4L: 1,
#  5L: 0,
#  6L: 0,
#  7L: 0,
#  8L: 0,
#  9L: 1,
#  10L: 1,
#  11L: 1,
#  12L: 1,
#  13L: 0,
#  14L: 0,
#  15L: 1,
#  16L: 1,
#  17L: 0,
#  18L: 0,
#  19L: 1,
#  20L: 1,
#  21L: 0,
#  22L: 0,
#  23L: 1,
#  24L: 0,
#  25L: 1,
#  26L: 1,
#  27L: 0,
#  28L: 0,
#  29L: 1,
#  30L: 0,
#  31L: 0,
#  32L: 1,
#  33L: 1,
#  34L: 0,
#  35L: 0,
#  36L: 0,
#  37L: 0,
#  38L: 0,
#  39L: 1,
#  40L: 1,
#  41L: 1,
#  42L: 1,
#  43L: 0,
#  44L: 1,
#  45L: 1,
#  46L: 0,
#  47L: 0,
#  48L: 1,
#  49L: 0,
#  50L: 1,
#  51L: 0,
#  52L: 0,
#  53L: 1,
#  54L: 1,
#  55L: 0,
#  56L: 0,
#  57L: 1,
#  58L: 0,
#  59L: 1,
#  60L: 0,
#  61L: 0,
#  62L: 1,
#  63L: 0,
#  64L: 0,
#  65L: 0,
#  66L: 0,
#  67L: 1,
#  68L: 0,
#  69L: 1,
#  70L: 0,
#  71L: 0,
#  72L: 1,
#  73L: 0,
#  74L: 0,
#  75L: 0,
#  76L: 0,
#  77L: 0,
#  78L: 0,
#  79L: 0,
#  80L: 1,
#  81L: 0,
#  82L: 0,
#  83L: 1,
#  84L: 0,
#  85L: 1,
#  86L: 1,
#  87L: 0,
#  88L: 0,
#  89L: 1,
#  90L: 0,
#  91L: 0,
# ...

# %%
# Change Python dictionary into Pandas dataframe

pred_df = pd.DataFrame(predictions.items(), columns = ['Id','Survival'])

# %%
pred_df.head()
# Out:
#    Id  Survival
# 0   1         0
# 1   2         1
# 2   3         1
# 3   4         1
# 4   5         0

# %%
pred_df[pred_df.Survival == 1].count()
# Out:
# Id          318
# Survival    318
# dtype: int64

# %% [markdown]
# ### This Third problem is the API data retrieval exercise. Last.fm

# %%
# Load required libraries

import json
import requests
import pandas as pd

# %%
# Establish dict of parameters for http request
parameters = {
              "method": "geo.gettopartists",
              "country": "Germany",
              "api_key": "f0920432cb7b78fc1cf1d8e93fb8e990",
              "format": "json"
              }

# %%
data = requests.get("http://ws.audioscrobbler.com/2.0/", params = parameters)
data = data.json()

# %%
data
# Out:
# {u'topartists': {u'@attr': {u'country': u'Germany',
#    u'page': u'1',
#    u'perPage': u'50',
#    u'total': u'500',
#    u'totalPages': u'10'},
#   u'artist': [{u'@attr': {u'rank': u'1'},
#     u'image': [{u'#text': u'http://userserve-ak.last.fm/serve/34/48391303.jpg',
#       u'size': u'small'},
#      {u'#text': u'http://userserve-ak.last.fm/serve/64/48391303.jpg',
#       u'size': u'medium'},
#      {u'#text': u'http://userserve-ak.last.fm/serve/126/48391303.jpg',
#       u'size': u'large'},
#      {u'#text': u'http://userserve-ak.last.fm/serve/252/48391303.jpg',
#       u'size': u'extralarge'},
#      {u'#text': u'http://userserve-ak.last.fm/serve/500/48391303/Marteria+0036.jpg',
#       u'size': u'mega'}],
#     u'listeners': u'4161',
#     u'mbid': u'58cc01f7-673c-4960-b913-4bc68118642a',
#     u'name': u'Marteria',
#     u'streamable': u'1',
#     u'url': u'http://www.last.fm/music/Marteria'},
#    {u'@attr': {u'rank': u'2'},
# ...

# %%
# Now get the top artist by indexing artist, first entry, and name

# %%
data['topartists']['artist'][0]['name']
# Out:
# u'Daft Punk'
